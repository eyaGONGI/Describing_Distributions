# %% [markdown]
# # Describing Distributions kurtic, Platykurtic)

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv('C:/Users/Dell/Downloads/medical_data.csv')
df.head(2)
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
#
#    Reflux_esophagitis Asthma     Services  Initial_days  TotalCharge  \
# 0                   0      1   Blood Work     10.585770  3726.702860
# 1                   1      0  Intravenous     15.129562  4193.190458
#
#    Additional_charges
# 0         17939.40342
# 1         17612.99812
#
# [2 rows x 32 columns]

# %% [markdown]
# ## VitD_levels

# %%
df.columns
# Out:
# Index(['State', 'Lat', 'Lng', 'Area', 'Children', 'Age', 'Income', 'Marital',
#        'Gender', 'ReAdmis', 'VitD_levels', 'Doc_visits', 'Full_meals_eaten',
#        'vitD_supp', 'Soft_drink', 'Initial_admin', 'HighBlood', 'Stroke',
#        'Complication_risk', 'Overweight', 'Arthritis', 'Diabetes',
#        'Hyperlipidemia', 'BackPain', 'Anxiety', 'Allergic_rhinitis',
#        'Reflux_esophagitis', 'Asthma', 'Services', 'Initial_days',
#        'TotalCharge', 'Additional_charges'],
#       dtype='object')

# %%
mean = df['VitD_levels'].mean()
median = df['VitD_levels'].median()
std = df['VitD_levels'].std()
mean_plus_one = mean +1
mean_minus_one = mean - 1

# %%
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot( df['VitD_levels'],ax=ax,stat='probability',kde=True)
#Add a line for the mean (red)
ax.axvline(mean, ls='--', color='red', label= f"Mean = {mean:.2f}") 
#Add a line for the median (green)
ax.axvline(median, ls='--', color='green', label= f"Median = {median:.2f}") 
#Add a line for for +1 std from the mean (black)
ax.axvline(mean_plus_one, color = 'black',label=f'+1 std = {mean_plus_one:,.2f}')
#Add a line for the - 1 std from the mean (black)
ax.axvline(mean_minus_one, color = 'black', label = f'-1 std = {mean_minus_one:,.2f}')
#Highlight the range between +1 and =1 std (yellow)
ax.axvspan(mean_plus_one, mean_minus_one, color = 'yellow',zorder=0)

ax.set_title('VitD Levels')
ax.legend();
plt.show()

### Calculate Kurtsis & Skew
kurtsis = stats.kurtosis(df['VitD_levels'], fisher = False)
print(f'Kurtosis = {kurtsis:.2f}')

skew = stats.skew(df['VitD_levels'])
print(f'Skew = {skew:.2f}')
# Out:
# Kurtosis = 3.01
# Skew = -0.00

# %% [markdown]
# * The distribution is  Continuous
# * The distribution doesn't have a  sew
# * )* It is  (Mesokurtc)

# %% [markdown]
# ## Doc_visits

# %%
mean = df['Doc_visits'].mean()
median = df['Doc_visits'].median()
std = df['Doc_visits'].std()
mean_plus_one = mean +1
mean_minus_one = mean - 1

# %%
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot( df['Doc_visits'],ax=ax,stat='probability',kde=True)
#Add a line for the mean (red)
ax.axvline(mean, ls='--', color='red', label= f"Mean = {mean:.2f}") 
#Add a line for the median (green)
ax.axvline(median, ls='--', color='green', label= f"Median = {median:.2f}") 
#Add a line for for +1 std from the mean (black)
ax.axvline(mean_plus_one, color = 'black',label=f'+1 std = {mean_plus_one:,.2f}')
#Add a line for the - 1 std from the mean (black)
ax.axvline(mean_minus_one, color = 'black', label = f'-1 std = {mean_minus_one:,.2f}')
#Highlight the range between +1 and =1 std (yellow)
ax.axvspan(mean_plus_one, mean_minus_one, color = 'yellow',zorder=0)

ax.set_title('Doc Visits')
ax.legend();
plt.show()

### Calculate Kurtsis & Skew
kurtsis = stats.kurtosis(df['Doc_visits'], fisher = False)
print(f'Kurtosis = {kurtsis:.2f}')

skew = stats.skew(df['Doc_visits'])
print(f'Skew = {skew:.2f}')
# Out:
# Kurtosis = 2.99
# Skew = 0.03

# %% [markdown]
# * The distribution is discrete
# * The distribution doesn't have a skew
# * The distribution is mesokurtic

# %% [markdown]
# ## TotalCharge

# %%
mean = df['TotalCharge'].mean()
median = df['TotalCharge'].median()
std = df['TotalCharge'].std()
mean_plus_one = mean +1
mean_minus_one = mean - 1

# %%
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot( df['TotalCharge'],ax=ax,stat='probability',kde=True)
#Add a line for the mean (red)
ax.axvline(mean, ls='--', color='red', label= f"Mean = {mean:.2f}") 
#Add a line for the median (green)
ax.axvline(median, ls='--', color='green', label= f"Median = {median:.2f}") 
#Add a line for for +1 std from the mean (black)
ax.axvline(mean_plus_one, color = 'black',label=f'+1 std = {mean_plus_one:,.2f}')
#Add a line for the - 1 std from the mean (black)
ax.axvline(mean_minus_one, color = 'black', label = f'-1 std = {mean_minus_one:,.2f}')
#Highlight the range between +1 and =1 std (yellow)
ax.axvspan(mean_plus_one, mean_minus_one, color = 'yellow',zorder=0)

ax.set_title('Total Charge')
ax.legend();
plt.show()

### Calculate Kurtsis & Skew
kurtsis = stats.kurtosis(df['TotalCharge'], fisher = False)
print(f'Kurtosis = {kurtsis:.2f}')

skew = stats.skew(df['TotalCharge'])
print(f'Skew = {skew:.2f}')
# Out:
# Kurtosis = 3.27
# Skew = 0.58

# %% [markdown]
# * The distribution is continuous
# * The distribution has a + skew
# * The distribution is mesokurtic
